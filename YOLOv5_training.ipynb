# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.
#
# Note ทดสอบบันทึกข้อความ

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %% [markdown]
# # Setup Google Drive
# Only one time after initial the google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Extract dataset
# สำคัญมาก!!! ถ้าต้องการอัพโหลด dataset.zip ใหม่ ควรลบโฟรเดอร์ dataset หรือ เปลี่ยนชื่อก่อนทำการ Run ชุดคำสั่งนี้ เพื่อป้องกันการซ้ำซ้อนของไฟล์

# %%
# Extract file
# !unzip /content/drive/MyDrive/dataset.zip -d /content/drive/MyDrive/dataset

# %%
# copy data.yaml to yolov5
# !cp /content/drive/MyDrive/dataset/data.yaml /content/yolov5/

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.7 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 3 persons, 1 bus, 11.8ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 1 person, 13.1ms
# Speed: 0.4ms pre-process, 12.5ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %% [markdown]
# # 2. Capture from Webcam

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: { facingMode: "user" }});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %% [markdown]
# # 2nd detection

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source photo.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=photo.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/photo.jpg: 384x640 1 bottle, 12.3ms
# Speed: 0.4ms pre-process, 12.3ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %% [markdown]
# # 3. Train

# %% [markdown]
# Prepare dataset from roboflow
# 1.   Upload
# 2.   Rename to Workshop_Dataset2.zip
# 3.   Run the code below
# 4. Move data.yaml to yolov4 folder

# %% [markdown]
# Install monitoring tools

# %%
# %pip install -q wandb
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: saruchay. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# Train a custom model

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data data.yaml --weights yolov5s.pt
# Out:
# wandb: Currently logged in as: saruchay. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Tracking run with wandb version 0.13.9
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20230115_074334-ebh872ab
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run autumn-wave-3
# wandb: ⭐️ View project at https://wandb.ai/saruchay/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/saruchay/YOLOv5/runs/ebh872ab
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7027720 parameters, 7027720 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/dataset/train/labels.cache... 138 images, 0 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
# val: Scanning /content/drive/MyDrive/dataset/valid/labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100% 13/13 [00:00<?, ?it/s]
#
# AutoAnchor: 5.06 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      3.74G     0.1131    0.03213    0.03948         20        640: 100% 9/9 [00:06<00:00,  1.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.60it/s]
#                    all         13         18   0.000228      0.037    0.00016   3.11e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      3.74G     0.1014    0.03069    0.03662         29        640: 100% 9/9 [00:04<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.32it/s]
#                    all         13         18    0.00115      0.231     0.0011   0.000312
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      3.74G    0.09023    0.02979    0.03225         22        640: 100% 9/9 [00:03<00:00,  2.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.44it/s]
#                    all         13         18    0.00307       0.68     0.0406     0.0136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      3.74G    0.08122     0.0338    0.02712         28        640: 100% 9/9 [00:04<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.76it/s]
#                    all         13         18    0.00356        0.8     0.0679     0.0194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      3.74G    0.07463    0.02923    0.02198         19        640: 100% 9/9 [00:04<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.49it/s]
#                    all         13         18      0.772      0.148      0.215     0.0399
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      3.74G     0.0682    0.02835    0.01699         27        640: 100% 9/9 [00:04<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.64it/s]
#                    all         13         18      0.455      0.548      0.453     0.0975
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      3.74G     0.0706    0.02739     0.0147         27        640: 100% 9/9 [00:04<00:00,  2.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.00it/s]
#                    all         13         18      0.409       0.37       0.55      0.193
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      3.74G     0.0706    0.02747    0.01131         27        640: 100% 9/9 [00:04<00:00,  2.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.67it/s]
#                    all         13         18      0.615      0.402      0.419      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      3.74G     0.0678    0.02604   0.008729         23        640: 100% 9/9 [00:04<00:00,  1.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.41it/s]
#                    all         13         18      0.514      0.463      0.294      0.094
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      3.74G    0.06477    0.02428   0.009453         25        640: 100% 9/9 [00:03<00:00,  2.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.13s/it]
#                    all         13         18      0.231      0.573      0.323     0.0729
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      3.74G    0.06611    0.02305   0.007788         18        640: 100% 9/9 [00:03<00:00,  2.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.59it/s]
#                    all         13         18      0.303      0.735      0.418     0.0917
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      3.74G    0.06322     0.0226   0.006759         22        640: 100% 9/9 [00:04<00:00,  2.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.10it/s]
#                    all         13         18      0.129      0.448      0.148      0.043
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      3.74G    0.06525    0.02072   0.006931         25        640: 100% 9/9 [00:04<00:00,  2.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.77it/s]
#                    all         13         18      0.171      0.672      0.258     0.0676
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      3.74G    0.06024    0.02191   0.005745         24        640: 100% 9/9 [00:04<00:00,  1.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.66it/s]
#                    all         13         18       0.34      0.409      0.314      0.101
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      3.74G    0.05687    0.02147   0.004999         30        640: 100% 9/9 [00:04<00:00,  2.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         13         18      0.197      0.763      0.359      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      3.74G    0.05833    0.02004   0.004792         20        640: 100% 9/9 [00:04<00:00,  2.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.87it/s]
#                    all         13         18      0.362      0.896      0.562      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      3.74G    0.05499    0.01915    0.00408         28        640: 100% 9/9 [00:04<00:00,  2.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.44it/s]
#                    all         13         18      0.423      0.867      0.603      0.237
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      3.74G    0.05428    0.01673   0.004761         19        640: 100% 9/9 [00:04<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.67it/s]
#                    all         13         18      0.754      0.793      0.834      0.395
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      3.74G    0.05195    0.01776   0.003952         23        640: 100% 9/9 [00:04<00:00,  2.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.99it/s]
#                    all         13         18      0.556       0.85      0.744      0.301
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      3.74G      0.054    0.01705   0.003584         26        640: 100% 9/9 [00:04<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.60s/it]
#                    all         13         18      0.667      0.899      0.794      0.276
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      3.74G     0.0495    0.01679   0.003398         20        640: 100% 9/9 [00:03<00:00,  2.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.55it/s]
#                    all         13         18      0.553       0.74      0.652       0.31
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      3.74G    0.04968    0.01523   0.003716         21        640: 100% 9/9 [00:03<00:00,  2.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.62it/s]
#                    all         13         18      0.431       0.85      0.528      0.266
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      3.74G    0.04893     0.0163   0.003136         16        640: 100% 9/9 [00:04<00:00,  2.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.87it/s]
#                    all         13         18      0.525      0.767      0.755       0.35
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      3.74G    0.04833    0.01435   0.002762         23        640: 100% 9/9 [00:04<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.59it/s]
#                    all         13         18      0.615      0.746      0.723      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      3.74G    0.04905    0.01528   0.003289         23        640: 100% 9/9 [00:04<00:00,  2.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  6.26it/s]
#                    all         13         18      0.595      0.933       0.79      0.235
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      3.74G    0.04793    0.01542   0.003042         26        640: 100% 9/9 [00:04<00:00,  2.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         13         18      0.437      0.713      0.573      0.198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      3.74G    0.04382    0.01532   0.002668         28        640: 100% 9/9 [00:04<00:00,  2.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.35it/s]
#                    all         13         18       0.66      0.978      0.778      0.317
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      3.74G    0.04574    0.01452   0.002496         25        640: 100% 9/9 [00:04<00:00,  2.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.66it/s]
#                    all         13         18      0.683       0.88      0.868      0.304
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      3.74G    0.04471    0.01341   0.002256         21        640: 100% 9/9 [00:04<00:00,  2.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.93it/s]
#                    all         13         18      0.782      0.902      0.888      0.319
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      3.74G    0.04425    0.01541   0.002835         28        640: 100% 9/9 [00:04<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.29s/it]
#                    all         13         18      0.834          1      0.929       0.31
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      3.74G    0.04154    0.01466   0.002379         27        640: 100% 9/9 [00:03<00:00,  2.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.80it/s]
#                    all         13         18      0.512       0.83      0.557      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      3.74G    0.04576    0.01288   0.002081         20        640: 100% 9/9 [00:04<00:00,  1.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.31it/s]
#                    all         13         18      0.823      0.912      0.904      0.343
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      3.74G    0.04404    0.01257    0.00265         15        640: 100% 9/9 [00:04<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.94it/s]
#                    all         13         18      0.726      0.847      0.822      0.249
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      3.74G    0.04115    0.01306   0.002109         23        640: 100% 9/9 [00:04<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.43it/s]
#                    all         13         18      0.809       0.83      0.871      0.352
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      3.74G    0.03972    0.01291   0.002646         24        640: 100% 9/9 [00:04<00:00,  2.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.84it/s]
#                    all         13         18      0.792      0.896      0.961      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      3.74G    0.03984    0.01352   0.002313         22        640: 100% 9/9 [00:03<00:00,  2.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.65it/s]
#                    all         13         18      0.973      0.933       0.97      0.392
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      3.74G    0.03823    0.01276   0.002218         18        640: 100% 9/9 [00:04<00:00,  1.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.04it/s]
#                    all         13         18      0.817      0.913      0.872      0.369
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      3.74G    0.03804    0.01258   0.001826         26        640: 100% 9/9 [00:04<00:00,  2.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.76it/s]
#                    all         13         18      0.856      0.933      0.926      0.433
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      3.74G    0.03819    0.01239   0.002098         21        640: 100% 9/9 [00:04<00:00,  2.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.36it/s]
#                    all         13         18      0.703      0.773      0.775      0.327
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      3.74G    0.03905    0.01372   0.002359         19        640: 100% 9/9 [00:04<00:00,  1.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.39s/it]
#                    all         13         18      0.874      0.867      0.886       0.31
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      3.74G    0.03646    0.01189   0.001701         13        640: 100% 9/9 [00:03<00:00,  2.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.82it/s]
#                    all         13         18      0.764      0.783       0.76      0.229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      3.74G     0.0375    0.01348   0.001923         16        640: 100% 9/9 [00:04<00:00,  2.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.59it/s]
#                    all         13         18      0.949      0.923      0.984      0.274
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      3.74G    0.03417    0.01203   0.001649         20        640: 100% 9/9 [00:04<00:00,  2.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.08it/s]
#                    all         13         18      0.687      0.813      0.694      0.258
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      3.74G    0.03808    0.01136   0.001587         19        640: 100% 9/9 [00:04<00:00,  1.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.35it/s]
#                    all         13         18      0.959      0.922      0.984      0.456
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      3.74G    0.03576    0.01304   0.001941         28        640: 100% 9/9 [00:04<00:00,  2.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.11it/s]
#                    all         13         18      0.966      0.982      0.995      0.386
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      3.74G     0.0348    0.01352   0.001992         35        640: 100% 9/9 [00:04<00:00,  2.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.76it/s]
#                    all         13         18      0.958      0.993      0.995      0.269
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      3.74G    0.03464    0.01157   0.001538         15        640: 100% 9/9 [00:04<00:00,  2.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all         13         18      0.816      0.876      0.892      0.369
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      3.74G    0.03583    0.01268   0.001911         29        640: 100% 9/9 [00:04<00:00,  2.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.86it/s]
#                    all         13         18       0.76      0.917       0.86      0.342
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      3.74G    0.03364    0.01357    0.00158         24        640: 100% 9/9 [00:04<00:00,  2.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.15it/s]
#                    all         13         18      0.974      0.867      0.957      0.397
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      3.74G    0.03512    0.01246   0.001817         19        640: 100% 9/9 [00:04<00:00,  1.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.38s/it]
#                    all         13         18      0.954      0.867      0.957      0.404
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      3.74G    0.03402     0.0123   0.001575         20        640: 100% 9/9 [00:03<00:00,  2.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.84it/s]
#                    all         13         18      0.842      0.783      0.859      0.326
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      3.74G    0.03609     0.0116   0.001482         27        640: 100% 9/9 [00:03<00:00,  2.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.80it/s]
#                    all         13         18      0.822          1      0.957      0.411
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      3.74G    0.03249    0.01154    0.00144         22        640: 100% 9/9 [00:04<00:00,  2.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.76it/s]
#                    all         13         18      0.842          1      0.957      0.376
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      3.74G    0.03319    0.01123    0.00172         25        640: 100% 9/9 [00:04<00:00,  2.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.70it/s]
#                    all         13         18       0.85      0.997      0.957      0.375
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      3.74G    0.03171    0.01112   0.001474         24        640: 100% 9/9 [00:04<00:00,  2.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.95it/s]
#                    all         13         18      0.852          1      0.938      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      3.74G    0.03337    0.01053   0.001417         23        640: 100% 9/9 [00:04<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.45it/s]
#                    all         13         18      0.872          1      0.938        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      3.74G    0.03167    0.01112   0.001298         23        640: 100% 9/9 [00:04<00:00,  2.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.60it/s]
#                    all         13         18      0.871          1       0.94      0.356
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      3.74G    0.03381    0.01141   0.002161         24        640: 100% 9/9 [00:04<00:00,  2.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.30it/s]
#                    all         13         18      0.859      0.995      0.949      0.371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      3.74G    0.03324    0.01251   0.001689         24        640: 100% 9/9 [00:03<00:00,  2.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.33it/s]
#                    all         13         18      0.807      0.933      0.857      0.354
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      3.74G    0.03112    0.01267   0.001406         23        640: 100% 9/9 [00:04<00:00,  1.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.74s/it]
#                    all         13         18       0.87          1      0.949      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      3.74G    0.03093    0.01027   0.001608         15        640: 100% 9/9 [00:03<00:00,  2.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.50it/s]
#                    all         13         18      0.886          1      0.957      0.519
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      3.74G    0.03026    0.01046   0.001328         23        640: 100% 9/9 [00:04<00:00,  2.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.61it/s]
#                    all         13         18      0.887          1      0.957      0.528
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      3.74G    0.03101    0.01015   0.001313         22        640: 100% 9/9 [00:04<00:00,  2.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.30it/s]
#                    all         13         18      0.947      0.933      0.976      0.408
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      3.74G    0.02974     0.0108   0.001179         17        640: 100% 9/9 [00:04<00:00,  2.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.70it/s]
#                    all         13         18      0.942      0.933      0.984      0.483
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      3.74G    0.03001    0.01126    0.00115         20        640: 100% 9/9 [00:04<00:00,  2.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.82it/s]
#                    all         13         18      0.959      0.933      0.984      0.439
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      3.74G    0.03049    0.01156   0.001388         25        640: 100% 9/9 [00:04<00:00,  2.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.30it/s]
#                    all         13         18      0.803      0.767      0.791      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      3.74G     0.0291    0.01024   0.001568         21        640: 100% 9/9 [00:04<00:00,  1.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all         13         18      0.972      0.933      0.984       0.59

# %% [markdown]
# # Detection
# Test from image

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source test1.jpg
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=test1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test1.jpg: 480x640 1 helmet, 1 pistol, 14.5ms
# Speed: 0.7ms pre-process, 14.5ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# Test from video

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source testvideo.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=testvideo.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 13.7ms
# video 1/1 (2/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (3/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (4/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.9ms
# video 1/1 (5/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.6ms
# video 1/1 (6/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 10.4ms
# video 1/1 (7/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (8/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (9/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (10/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (11/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (12/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (13/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (14/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 12.6ms
# video 1/1 (15/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.7ms
# video 1/1 (16/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (17/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.7ms
# video 1/1 (18/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (19/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (20/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (21/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.9ms
# video 1/1 (22/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (23/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (24/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (25/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (26/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (27/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (28/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (29/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (30/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (31/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (32/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.6ms
# video 1/1 (33/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (34/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.6ms
# video 1/1 (35/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (36/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 8.9ms
# video 1/1 (37/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (38/369) /content/yolov5/testvideo.mp4: 384x640 2 helmets, 9.5ms
# video 1/1 (39/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (40/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (41/369) /content/yolov5/testvideo.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (42/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (43/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (44/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (45/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (46/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (47/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (48/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (49/369) /content/yolov5/testvideo.mp4: 384x640 2 helmets, 8.9ms
# video 1/1 (50/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (51/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (52/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 12.3ms
# video 1/1 (53/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (54/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (55/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (56/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (57/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (58/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (59/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.1ms
# video 1/1 (60/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (61/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (62/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (63/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 20.4ms
# video 1/1 (64/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (65/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (66/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.7ms
# video 1/1 (67/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (68/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (69/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (70/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (71/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (72/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.4ms
# video 1/1 (73/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.2ms
# video 1/1 (74/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (75/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (76/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (77/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (78/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.9ms
# video 1/1 (79/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (80/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (81/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (82/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (83/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (84/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (85/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (86/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (87/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (88/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (89/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (90/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.1ms
# video 1/1 (91/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (92/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.9ms
# video 1/1 (93/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (94/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.8ms
# video 1/1 (95/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.9ms
# video 1/1 (96/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (97/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (98/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (99/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.0ms
# video 1/1 (100/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (101/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.8ms
# video 1/1 (102/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (103/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (104/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (105/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.6ms
# video 1/1 (106/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (107/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (108/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.8ms
# video 1/1 (109/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (110/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 14.3ms
# video 1/1 (111/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (112/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (113/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (114/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (115/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (116/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (117/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (118/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.3ms
# video 1/1 (119/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.5ms
# video 1/1 (120/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (121/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (122/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.9ms
# video 1/1 (123/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (124/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (125/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (126/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (127/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (128/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (129/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (130/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (131/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.8ms
# video 1/1 (132/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 16.0ms
# video 1/1 (133/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (134/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.7ms
# video 1/1 (135/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (136/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 14.8ms
# video 1/1 (137/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (138/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (139/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (140/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (141/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (142/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (143/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (144/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 13.6ms
# video 1/1 (145/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (146/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (147/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.9ms
# video 1/1 (148/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.0ms
# video 1/1 (149/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (150/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.2ms
# video 1/1 (151/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.7ms
# video 1/1 (152/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.9ms
# video 1/1 (153/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (154/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.1ms
# video 1/1 (155/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.4ms
# video 1/1 (156/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (157/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (158/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (159/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.4ms
# video 1/1 (160/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.8ms
# video 1/1 (161/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (162/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.1ms
# video 1/1 (163/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.3ms
# video 1/1 (164/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (165/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.5ms
# video 1/1 (166/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (167/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (168/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (169/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (170/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (171/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (172/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (173/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.2ms
# video 1/1 (174/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.4ms
# video 1/1 (175/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.9ms
# video 1/1 (176/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.8ms
# video 1/1 (177/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.2ms
# video 1/1 (178/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (179/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.1ms
# video 1/1 (180/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.9ms
# video 1/1 (181/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (182/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (183/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (184/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (185/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (186/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.0ms
# video 1/1 (187/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (188/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.6ms
# video 1/1 (189/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (190/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (191/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (192/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (193/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.7ms
# video 1/1 (194/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.4ms
# video 1/1 (195/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (196/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (197/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (198/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 13.4ms
# video 1/1 (199/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (200/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (201/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 14.2ms
# video 1/1 (202/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (203/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (204/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (205/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (206/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (207/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (208/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (209/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (210/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.9ms
# video 1/1 (211/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 12.0ms
# video 1/1 (212/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 12.3ms
# video 1/1 (213/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (214/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.4ms
# video 1/1 (215/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (216/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (217/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (218/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (219/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (220/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (221/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (222/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (223/369) /content/yolov5/testvideo.mp4: 384x640 2 helmets, 8.7ms
# video 1/1 (224/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (225/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (226/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.6ms
# video 1/1 (227/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.3ms
# video 1/1 (228/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.4ms
# video 1/1 (229/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.7ms
# video 1/1 (230/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (231/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.8ms
# video 1/1 (232/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (233/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.3ms
# video 1/1 (234/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (235/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (236/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (237/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 13.0ms
# video 1/1 (238/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (239/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.4ms
# video 1/1 (240/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (241/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.4ms
# video 1/1 (242/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (243/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.4ms
# video 1/1 (244/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (245/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (246/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.4ms
# video 1/1 (247/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (248/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 14.3ms
# video 1/1 (249/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.9ms
# video 1/1 (250/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (251/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.3ms
# video 1/1 (252/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (253/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 11.9ms
# video 1/1 (254/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.3ms
# video 1/1 (255/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.3ms
# video 1/1 (256/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.3ms
# video 1/1 (257/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.8ms
# video 1/1 (258/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (259/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (260/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.3ms
# video 1/1 (261/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.4ms
# video 1/1 (262/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.8ms
# video 1/1 (263/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (264/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 11.1ms
# video 1/1 (265/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.2ms
# video 1/1 (266/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.0ms
# video 1/1 (267/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 11.2ms
# video 1/1 (268/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (269/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (270/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.3ms
# video 1/1 (271/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (272/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (273/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (274/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (275/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (276/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.3ms
# video 1/1 (277/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.0ms
# video 1/1 (278/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (279/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (280/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (281/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 12.1ms
# video 1/1 (282/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (283/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (284/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (285/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (286/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.6ms
# video 1/1 (287/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (288/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (289/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.8ms
# video 1/1 (290/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.4ms
# video 1/1 (291/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.0ms
# video 1/1 (292/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.7ms
# video 1/1 (293/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (294/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 13.9ms
# video 1/1 (295/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.1ms
# video 1/1 (296/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (297/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.3ms
# video 1/1 (298/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.9ms
# video 1/1 (299/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 11.3ms
# video 1/1 (300/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.7ms
# video 1/1 (301/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (302/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (303/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.0ms
# video 1/1 (304/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.5ms
# video 1/1 (305/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (306/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.8ms
# video 1/1 (307/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (308/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.1ms
# video 1/1 (309/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (310/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (311/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (312/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (313/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.1ms
# video 1/1 (314/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (315/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.4ms
# video 1/1 (316/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.9ms
# video 1/1 (317/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (318/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.5ms
# video 1/1 (319/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 11.2ms
# video 1/1 (320/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.3ms
# video 1/1 (321/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.4ms
# video 1/1 (322/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (323/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 9.2ms
# video 1/1 (324/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.7ms
# video 1/1 (325/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.4ms
# video 1/1 (326/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.3ms
# video 1/1 (327/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (328/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 10.0ms
# video 1/1 (329/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (330/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.5ms
# video 1/1 (331/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (332/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (333/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.1ms
# video 1/1 (334/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (335/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.1ms
# video 1/1 (336/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.3ms
# video 1/1 (337/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.8ms
# video 1/1 (338/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (339/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (340/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 8.6ms
# video 1/1 (341/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.2ms
# video 1/1 (342/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (343/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (344/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.1ms
# video 1/1 (345/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.4ms
# video 1/1 (346/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (347/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (348/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.4ms
# video 1/1 (349/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (350/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (351/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.0ms
# video 1/1 (352/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 12.6ms
# video 1/1 (353/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# video 1/1 (354/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (355/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (356/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (357/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (358/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.8ms
# video 1/1 (359/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.4ms
# video 1/1 (360/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (361/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.4ms
# video 1/1 (362/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.9ms
# video 1/1 (363/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.1ms
# video 1/1 (364/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 10.8ms
# video 1/1 (365/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (366/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.6ms
# video 1/1 (367/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 9.5ms
# video 1/1 (368/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.5ms
# video 1/1 (369/369) /content/yolov5/testvideo.mp4: 384x640 1 helmet, 1 pistol, 8.7ms
# Speed: 0.4ms pre-process, 9.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
